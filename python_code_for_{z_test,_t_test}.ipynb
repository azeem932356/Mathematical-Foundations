# %% [markdown]
# <a href="https://colab.research.google.com/github/azeem932356/Mathematical-Foundations/blob/main/python_code_for_%7Bz_test%2C_t_test%7D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Z-Test:**
#
# suppose the IQ in a certain population is normal distribution with a mean of μ = 100 and standard deviation of σ (sigma) = 15
# a researcher wants to know if a new drug affects IQ levels, so he recurites 20 patients to try it and record their IQ levels
#
#
# The following code shows how to perform **Z-test** in python and determine if new drug causes significant different IQ level

# %%
from statsmodels.stats.weightstats import ztest as ztest

#Enter IQ levels from 20 patients
data = [88, 92, 94, 94, 96, 97, 97, 97, 99, 99, 105, 109, 109, 109, 110, 112, 112, 112, 114, 115]

# %%
#ztest
z_stat, p_value = ztest(data, value=100)

print(f"Z-statistic: {z_stat}")
print(f"P-value: {p_value}")

# %% [markdown]
# we reject the null hypothesis H0
#
# **z-test** = 1.582295902196661 > **P-value**: 0.11358203578598267

# %% [markdown]
# **Internl**
#
# 1. **Problem Statement**
#    "Does a new drug affect IQ?"
#
#                    ↓
#
# 2. Collect Data
#    20 patients, IQ scores recorded
#
#
#                   ↓
# 3. Sample Statistics
#    Mean = 100.4, Std Dev = 8.39
#
#                   ↓
# 4. Set Up Hypotheses
#    H₀: μ = 100 (No effect)
#    H₁: μ ≠ 100 (Does affect)
#
#                   ↓
# 5. Choose Alpha
#    α = 0.05
#
#                    ↓
# 6. Choose Test
#    Z-test (population σ known)
#
#                   ↓
# 7. Calculate Test Statistic
#    Z = 1.5823
#
#                  ↓
# 8. Find Critical Value
#    ±1.96 (for two-tailed, α = 0.05)
#
#                   ↓
# 9. Compare Z to Critical Value
#    1.5823 < 1.96 → FAIL TO REJECT
#
#                  ↓
# 10. Calculate P-value
#     P = 0.1136
#
#                 ↓
# 11. Compare P to Alpha
#     0.1136 > 0.05 → FAIL TO REJECT
#
#                ↓
# 12. Final Decision
#     ❌ Drug does NOT significantly affect IQ.

# %% [markdown]
# **t-test**
#
# used to determine if there is a significant difference between the means of two groups

# %%
##consider this as population
ages = [10,20,35,50,28,40,55,18,16,55,30,25,43,18,30,28,14,24,16,17,32,35,26,27,65,18,43,23,21,20,19,70]

# %%
import numpy as np
ages_mean = np.mean(ages)
print(ages_mean)
# Out:
# 30.34375

# %%
##sample
sample_size = 10
age_sample = np.random.choice(ages, sample_size)
age_sample
# Out:
# array([20, 19, 55, 55, 43, 10, 20, 19, 40, 26])

# %%
from scipy.stats import ttest_1samp

# %%
ttest_1samp(age_sample, 30)
# Out:
# TtestResult(statistic=np.float64(0.13634926399074626), pvalue=np.float64(0.894546406873298), df=np.int64(9))

# %%
#consider another example
#ages of the college students(populataion)
#1 class students mean of all the ages
#Is Class A similar to the whole college in terms of average age?

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import math

# %%
np.random.seed(6)
#generates a fake population (school_ages) of students with average age around 53 (18 + after getting mu= value it adds 18)
school_ages = stats.poisson.rvs(loc= 18, mu = 35, size = 1500)
classA_ages = stats.poisson.rvs(loc = 18, mu = 30, size = 60)

# %%
classA_ages.mean()
# Out:
# np.float64(46.9)

# %%
_,p_value = ttest_1samp(classA_ages, popmean= school_ages.mean())
p_value
# Out:
# np.float64(1.139027071016194e-13)

# %%
school_ages.mean()
# Out:
# np.float64(53.303333333333335)

# %%
if p_value < 0.05:
    print("Reject H0")
else:
    print("Fail to Reject H0")
# Out:
# Reject H0

# %% [markdown]
# Population (1500 students)
#
#         ↓
# Calculate Population Mean
#
#         ↓
# Take Sample (60 students)
#
#         ↓
# Ask:
# Is Sample Mean = Population Mean?
#
#         ↓
# H₀: Equal
# H₁: Not Equal
#
#         ↓
# Run t-test
#
#         ↓
# Get t-statistic and p-value
#
#         ↓
# p-value < α ?
#
#         ↓
# Yes
#
#         ↓
# Reject H₀
#
#         ↓
# Conclude:
# Class A is different from the college

# %%
#Even if you restart and run 100 times, you get the EXACT SAME numbers.    np.random.seed(6)
import numpy as np
np.random.seed(6)
print(np.random.random())
print(np.random.random())
# Out:
# 0.8928601514360016
# 0.3319798053011772

# %%
#Every time you restart and run, you get DIFFERENT numbers.
import numpy as np
print(np.random.random())
print(np.random.random())
# Out:
# 0.8212291230578318
# 0.0416966257252499

# %%
#correlation
import seaborn as sns
df = sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#df.corr()
df.select_dtypes(include='number').corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.pairplot(df)

# %%
import numpy as np
import seaborn as sns

data = np.random.lognormal(mean=3, sigma=0.5, size=1000)

sns.histplot(data, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import numpy as np
import seaborn as sns

data = np.random.lognormal(mean=3, sigma=1.5, size=1000)

sns.histplot(np.log(data), kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

data = np.random.lognormal(mean=3, sigma=1.5, size=1000)

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.histplot(data, kde=True)
plt.title("Log-Normal Data")

plt.subplot(1,2,2)
sns.histplot(np.log(data), kde=True)
plt.title("After Log Transform")

plt.show()

# %%
from scipy.stats import bernoulli

data = bernoulli.rvs(p=0.7, size=10)

print(data)
# Out:
# [1 1 0 1 1 1 1 1 1 1]
